# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Netflix Userbase.csv")
df
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
df.head()
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
df.describe()
# Out:
#           User ID  Monthly Revenue          Age
# count  2500.00000      2500.000000  2500.000000
# mean   1250.50000        12.508400    38.795600
# std     721.83216         1.686851     7.171778
# min       1.00000        10.000000    26.000000
# 25%     625.75000        11.000000    32.000000
# 50%    1250.50000        12.000000    39.000000
# 75%    1875.25000        14.000000    45.000000
# max    2500.00000        15.000000    51.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %%
df.nunique()
# Out:
# User ID              2500
# Subscription Type       3
# Monthly Revenue         6
# Join Date             300
# Last Payment Date      26
# Country                10
# Age                    26
# Gender                  2
# Device                  4
# Plan Duration           1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %%
average_revenue = df.groupby("Subscription Type")["Monthly Revenue"].mean()
print(average_revenue)
# Out:
# Subscription Type
# Basic       12.481481
# Premium     12.590723
# Standard    12.464844
# Name: Monthly Revenue, dtype: float64

# %%
country = df.groupby("Country")["User ID"].count()
print(country)
# Out:
# Country
# Australia         183
# Brazil            183
# Canada            317
# France            183
# Germany           183
# Italy             183
# Mexico            183
# Spain             451
# United Kingdom    183
# United States     451
# Name: User ID, dtype: int64

# %%
age = df.groupby("Plan Duration")["Age"].median()
print(age)
# Out:
# Plan Duration
# 1 Month    39.0
# Name: Age, dtype: float64

# %%
gender = df.groupby("Gender")["Monthly Revenue"].sum()
print(gender)
# Out:
# Gender
# Female    15736
# Male      15535
# Name: Monthly Revenue, dtype: int64

# %%
average_device_age = df.groupby("Device")["Age"].mean()
print(average_device_age)
# Out:
# Device
# Laptop        39.036164
# Smart TV      38.693443
# Smartphone    38.726248
# Tablet        38.720379
# Name: Age, dtype: float64

# %%
plt.figure(figsize =(10,6))
sns.scatterplot(x="Age", y="Monthly Revenue", hue="Gender",data=df)
plt.xlabel=("Age")
plt.ylabel=("Monthly Revenue")
plt.title("Age & Monthly Revenue")
plt.show()

# %%
average_revenue_by_country = df.groupby("Country")["Monthly Revenue"].mean().reset_index()
sns.barplot(x="Country", y="Monthly Revenue", data=average_revenue_by_country)
plt.title("Revenue by Country")
plt.xlabel("Country")
plt.ylabel("Average Monthly Revenue")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       2 sns.barplot(x="Country", y="Monthly Revenue", data=average_revenue_by_country)
#       3 plt.title("Revenue by Country")
# ----> 4 plt.xlabel("Country")
#       5 plt.ylabel("Average Monthly Revenue")
#       6 plt.show()
#
# TypeError: 'str' object is not callable

# %%
sns.countplot(x='Subscription Type', data = df, color = 'green')
plt.title('Subscription Type Distribution')
plt.xlabel('Subscription Type')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 sns.countplot(x='Subscription Type', data = df, color = 'green')
#       2 plt.title('Subscription Type Distribution')
# ----> 3 plt.xlabel('Subscription Type')
#       4 plt.ylabel('Count')
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
sns.histplot(df["Monthly Revenue"], bins=5,kde=True)
plt.title('Monthly revenue Distribution')
plt.xlabel('Revenue Type')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 3
#       1 sns.histplot(df["Monthly Revenue"], bins=5,kde=True)
#       2 plt.title('Monthly revenue Distribution')
# ----> 3 plt.xlabel('Revenue Type')
#       4 plt.ylabel('Count')
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
sns.histplot(df["Age"], bins=5,kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 sns.histplot(df["Age"], bins=5,kde=True)
#       2 plt.title('Age Distribution')
# ----> 3 plt.xlabel('Age')
#       4 plt.ylabel('Count')
#       5 plt.show()
#
# TypeError: 'str' object is not callable
